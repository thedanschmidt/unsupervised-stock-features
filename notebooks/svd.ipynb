# %% [markdown]
# # SVD of Minute-Market-Data
# ### Dan Schmidt's Script Fall 2016

# %%
# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2
import os
import sys

# add the 'src' directory as one where we can import modules
src_dir = os.path.join(os.getcwd(), os.pardir, 'src')
sys.path.append(src_dir)
# %aimport preprocess
from preprocess.process import get_symbol
from preprocess.process import get_symbols_matrix
from preprocess.process import df_to_returns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path
from IPython.core.debugger import Tracer
import scipy as sp
from scipy.linalg import svd
from sklearn.decomposition import PCA
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Preprocessing
# Read the data in, convert dates to a useful format

# %%
data_loc = "/home/dan/code/market_data/"
symbols = [line.rstrip('\n') for line in open(data_loc+'sp500.txt')]

# Running the SVD on two weeks in 2015, check error on next week
train_start_date = "03/02/2015"
train_end_date = "03/14/2015"

test_start_date = "03/15/2015"
test_end_date = "03/21/2015"

#aapl = get_symbol("AAPL", data_loc, train_start_date, train_end_date)

test_symbols = symbols[:250]
print(test_symbols)

test_mat, syms = get_symbols_matrix(
    test_symbols, data_loc, train_start_date, train_end_date
)
# Out:
# ['AAL', 'AAPL', 'AAP', 'AA', 'ABBV', 'ABC', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'ADS', 'AEE', 'AEP', 'AES', 'AET', 'AFL', 'AGN', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALLE', 'ALL', 'ALXN', 'AMAT', 'AME', 'AMGN', 'AMG', 'AMP', 'AMT', 'AMZN', 'ANTM', 'AN', 'AON', 'APA', 'APC', 'APD', 'APH', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'A', 'AZO', 'BAC', 'BAX', 'BA', 'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BF-B', 'BHI', 'BIIB', 'BK', 'BLK', 'BLL', 'BMY', 'BRK-B', 'BSX', 'BWA', 'BXP', 'CAG', 'CAH', 'CAT', 'CA', 'CBG', 'CBS', 'CB', 'CCI', 'CCL', 'CELG', 'CERN', 'CFG', 'CF', 'CHD', 'CHK', 'CHRW', 'CHTR', 'CINF', 'CI', 'CLX', 'CL', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH', 'COL', 'COO', 'COP', 'COST', 'COTY', 'CPB', 'CRM', 'CSCO', 'CSRA', 'CSX', 'CTAS', 'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'C', 'DAL', 'DD', 'DE', 'DFS', 'DGX', 'DG', 'DHI', 'DHR', 'DISCA', 'DISCK', 'DIS', 'DLPH', 'DLR', 'DLTR', 'DNB', 'DOV', 'DOW', 'DPS', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'D', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR', 'ENDP', 'EOG', 'EQIX', 'EQR', 'EQT', 'ESRX', 'ESS', 'ES', 'ETFC', 'ETN', 'ETR', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'FAST', 'FBHS', 'FB', 'FCX', 'FDX', 'FE', 'FFIV', 'FISV', 'FIS', 'FITB', 'FLIR', 'FLR', 'FLS', 'FL', 'FMC', 'FOXA', 'FRT', 'FSLR', 'FTI', 'FTR', 'FTV', 'F', 'GD', 'GE', 'GGP', 'GILD', 'GIS', 'GLW', 'GM', 'GOOGL', 'GOOG', 'GPC', 'GPN', 'GPS', 'GRMN', 'GS', 'GT', 'GWW', 'HAL', 'HAR', 'HAS', 'HBAN', 'HBI', 'HCA', 'HCN', 'HCP', 'HD', 'HES', 'HIG', 'HOG', 'HOLX', 'HON', 'HPE', 'HPQ', 'HP', 'HRB', 'HRL', 'HRS', 'HSIC', 'HST', 'HSY', 'HUM', 'IBM', 'ICE', 'IFF', 'ILMN', 'INTC', 'INTU', 'IPG', 'IP', 'IRM', 'IR', 'ISRG', 'ITW', 'IVZ', 'JBHT', 'JCI', 'JEC']
# Reading AAL from pickle
# Reading AAPL from pickle
# Reading AAP from pickle
# AAP failed integrity check
# Reading AA from pickle
# Reading ABBV from pickle
# Reading ABC from pickle
# Reading ABT from pickle
# Reading ACN from pickle
# Reading ADBE from pickle
# ADBE failed integrity check
# Reading ADI from pickle
# ADI failed integrity check
# Reading ADM from pickle
# Reading ADP from pickle
# ADP failed integrity check
# Reading ADSK from pickle
# ADSK failed integrity check
# Reading ADS from pickle
# ADS failed integrity check
# Reading AEE from pickle
# Reading AEP from pickle
# Reading AES from pickle
# Reading AET from pickle
# Reading AFL from pickle
# Reading AGN from pickle
# Reading AIG from pickle
# Reading AIV from pickle
# AIV failed integrity check
# Reading AIZ from pickle
# AIZ failed integrity check
# Reading AJG from pickle
# AJG failed integrity check
# Reading AKAM from pickle
# AKAM failed integrity check
# Reading ALB from pickle
# ALB failed integrity check
# Reading ALK from pickle
# ALK failed integrity check
# Reading ALLE from pickle
# ALLE failed integrity check
# Reading ALL from pickle
# Reading ALXN from pickle
# ALXN failed integrity check
# Reading AMAT from pickle
# Reading AME from pickle
# AME failed integrity check
# Reading AMGN from pickle
# Reading AMG from pickle
# AMG failed integrity check
# Reading AMP from pickle
# AMP failed integrity check
# Reading AMT from pickle
# Reading AMZN from pickle
# Reading ANTM from pickle
# ANTM failed integrity check
# Reading AN from pickle
# AN failed integrity check
# Reading AON from pickle
# AON failed integrity check
# Reading APA from pickle
# Reading APC from pickle
# Reading APD from pickle
# APD failed integrity check
# Reading APH from pickle
# APH failed integrity check
# Reading ATVI from pickle
# Reading AVB from pickle
# AVB failed integrity check
# Reading AVGO from pickle
# Reading AVY from pickle
# AVY failed integrity check
# Reading AWK from pickle
# AWK failed integrity check
# Reading AXP from pickle
# Reading AYI from pickle
# AYI failed integrity check
# Reading A from pickle
# A failed integrity check
# Reading AZO from pickle
# AZO failed integrity check
# Reading BAC from pickle
# Reading BAX from pickle
# Reading BA from pickle
# Reading BBBY from pickle
# BBBY failed integrity check
# Reading BBT from pickle
# Reading BBY from pickle
# Reading BCR from pickle
# BCR failed integrity check
# Reading BDX from pickle
# BDX failed integrity check
# Reading BEN from pickle
# BEN failed integrity check
# Reading BF-B from pickle
# BF-B failed integrity check
# Reading BHI from pickle
# Reading BIIB from pickle
# BIIB failed integrity check
# Reading BK from pickle
# Reading BLK from pickle
# BLK failed integrity check
# Reading BLL from pickle
# BLL failed integrity check
# Reading BMY from pickle
# Reading BRK-B from pickle
# Reading BSX from pickle
# Reading BWA from pickle
# BWA failed integrity check
# Reading BXP from pickle
# BXP failed integrity check
# Reading CAG from pickle
# CAG failed integrity check
# Reading CAH from pickle
# CAH failed integrity check
# Reading CAT from pickle
# Reading CA from pickle
# CA failed integrity check
# Reading CBG from pickle
# CBG failed integrity check
# Reading CBS from pickle
# Reading CB from pickle
# CB failed integrity check
# Reading CCI from pickle
# Reading CCL from pickle
# Reading CELG from pickle
# Reading CERN from pickle
# CERN failed integrity check
# Reading CFG from pickle
# CFG failed integrity check
# Reading CF from pickle
# CF failed integrity check
# Reading CHD from pickle
# CHD failed integrity check
# Reading CHK from pickle
# Reading CHRW from pickle
# CHRW failed integrity check
# Reading CHTR from pickle
# CHTR failed integrity check
# Reading CINF from pickle
# CINF failed integrity check
# Reading CI from pickle
# CI failed integrity check
# Reading CLX from pickle
# CLX failed integrity check
# Reading CL from pickle
# Reading CMA from pickle
# CMA failed integrity check
# Reading CMCSA from pickle
# Reading CME from pickle
# CME failed integrity check
# Reading CMG from pickle
# CMG failed integrity check
# Reading CMI from pickle
# CMI failed integrity check
# Reading CMS from pickle
# Reading CNC from pickle
# CNC failed integrity check
# Reading CNP from pickle
# Reading COF from pickle
# Reading COG from pickle
# Reading COH from pickle
# Reading COL from pickle
# COL failed integrity check
# Reading COO from pickle
# COO failed integrity check
# Reading COP from pickle
# Reading COST from pickle
# Reading COTY from pickle
# COTY failed integrity check
# Reading CPB from pickle
# CPB failed integrity check
# Reading CRM from pickle
# Reading CSCO from pickle
# Reading CSRA from pickle
# Reading CSX from pickle
# Reading CTAS from pickle
# CTAS failed integrity check
# Reading CTL from pickle
# Reading CTSH from pickle
# Reading CTXS from pickle
# CTXS failed integrity check
# Reading CVS from pickle
# Reading CVX from pickle
# Reading CXO from pickle
# CXO failed integrity check
# Reading C from pickle
# Reading DAL from pickle
# Reading DD from pickle
# Reading DE from pickle
# Reading DFS from pickle
# Reading DGX from pickle
# DGX failed integrity check
# Reading DG from pickle
# Reading DHI from pickle
# Reading DHR from pickle
# Reading DISCA from pickle
# Reading DISCK from pickle
# DISCK failed integrity check
# Reading DIS from pickle
# Reading DLPH from pickle
# DLPH failed integrity check
# Reading DLR from pickle
# DLR failed integrity check
# Reading DLTR from pickle
# Reading DNB from pickle
# DNB failed integrity check
# Reading DOV from pickle
# DOV failed integrity check
# Reading DOW from pickle
# Reading DPS from pickle
# DPS failed integrity check
# Reading DRI from pickle
# DRI failed integrity check
# Reading DTE from pickle
# DTE failed integrity check
# Reading DUK from pickle
# Reading DVA from pickle
# DVA failed integrity check
# Reading DVN from pickle
# Reading D from pickle
# Reading EA from pickle
# Reading EBAY from pickle
# Reading ECL from pickle
# ECL failed integrity check
# Reading ED from pickle
# Reading EFX from pickle
# EFX failed integrity check
# Reading EIX from pickle
# Reading EL from pickle
# EL failed integrity check
# Reading EMN from pickle
# EMN failed integrity check
# Reading EMR from pickle
# Reading ENDP from pickle
# ENDP failed integrity check
# Reading EOG from pickle
# Reading EQIX from pickle
# EQIX failed integrity check
# Reading EQR from pickle
# EQR failed integrity check
# Reading EQT from pickle
# EQT failed integrity check
# Reading ESRX from pickle
# Reading ESS from pickle
# ESS failed integrity check
# Reading ES from pickle
# ES failed integrity check
# Reading ETFC from pickle
# ETFC failed integrity check
# Reading ETN from pickle
# Reading ETR from pickle
# ETR failed integrity check
# Reading EW from pickle
# EW failed integrity check
# Reading EXC from pickle
# Reading EXPD from pickle
# EXPD failed integrity check
# Reading EXPE from pickle
# EXPE failed integrity check
# Reading EXR from pickle
# EXR failed integrity check
# Reading FAST from pickle
# Reading FBHS from pickle
# FBHS failed integrity check
# Reading FB from pickle
# Reading FCX from pickle
# Reading FDX from pickle
# FDX failed integrity check
# Reading FE from pickle
# Reading FFIV from pickle
# FFIV failed integrity check
# Reading FISV from pickle
# FISV failed integrity check
# Reading FIS from pickle
# FIS failed integrity check
# Reading FITB from pickle
# Reading FLIR from pickle
# FLIR failed integrity check
# Reading FLR from pickle
# FLR failed integrity check
# Reading FLS from pickle
# FLS failed integrity check
# Reading FL from pickle
# Reading FMC from pickle
# FMC failed integrity check
# Reading FOXA from pickle
# Reading FRT from pickle
# FRT failed integrity check
# Reading FSLR from pickle
# Reading FTI from pickle
# Reading FTR from pickle
# Reading FTV from pickle
# Reading F from pickle
# Reading GD from pickle
# GD failed integrity check
# Reading GE from pickle
# Reading GGP from pickle
# Reading GILD from pickle
# Reading GIS from pickle
# Reading GLW from pickle
# Reading GM from pickle
# Reading GOOGL from pickle
# Reading GOOG from pickle
# GOOG failed integrity check
# Reading GPC from pickle
# GPC failed integrity check
# Reading GPN from pickle
# GPN failed integrity check
# Reading GPS from pickle
# Reading GRMN from pickle
# GRMN failed integrity check
# Reading GS from pickle
# Reading GT from pickle
# GT failed integrity check
# Reading GWW from pickle
# GWW failed integrity check
# Reading HAL from pickle
# Reading HAR from pickle
# HAR failed integrity check
# Reading HAS from pickle
# HAS failed integrity check
# Reading HBAN from pickle
# Reading HBI from pickle
# HBI failed integrity check
# Reading HCA from pickle
# Reading HCN from pickle
# Reading HCP from pickle
# Reading HD from pickle
# Reading HES from pickle
# Reading HIG from pickle
# Reading HOG from pickle
# HOG failed integrity check
# Reading HOLX from pickle
# HOLX failed integrity check
# Reading HON from pickle
# Reading HPE from pickle
# Reading HPQ from pickle
# Reading HP from pickle
# Reading HRB from pickle
# Reading HRL from pickle
# HRL failed integrity check
# Reading HRS from pickle
# HRS failed integrity check
# Reading HSIC from pickle
# HSIC failed integrity check
# Reading HST from pickle
# Reading HSY from pickle
# HSY failed integrity check
# Reading HUM from pickle
# HUM failed integrity check
# Reading IBM from pickle
# Reading ICE from pickle
# ICE failed integrity check
# Reading IFF from pickle
# IFF failed integrity check
# Reading ILMN from pickle
# ILMN failed integrity check
# Reading INTC from pickle
# Reading INTU from pickle
# INTU failed integrity check
# Reading IPG from pickle
# IPG failed integrity check
# Reading IP from pickle
# Reading IRM from pickle
# IRM failed integrity check
# Reading IR from pickle
# IR failed integrity check
# Reading ISRG from pickle
# ISRG failed integrity check
# Reading ITW from pickle
# ITW failed integrity check
# Reading IVZ from pickle
# Reading JBHT from pickle
# JBHT failed integrity check
# Reading JCI from pickle
# Reading JEC from pickle
# JEC failed integrity check

# %%
X = test_mat.values.T

# Remove the mean (which roughly removes linear 2-week trend)
Xmean = X.mean(axis=0)
Xd = X-Xmean
#Xd = X

print(Xd.shape)
# Try the SVD
U, S, VT = svd(X)
# Out:
# (122, 3898)

# %%
print(U.shape)
print(S.shape)
print(VT.shape)
print(Xmean.shape)
# Out:
# (122, 122)
# (122,)
# (3898, 3898)
# (3898,)

# %%
pca = PCA(svd_solver='randomized')
pca.fit(Xd)

plt.plot(pca.explained_variance_)
plt.show()

market = pca.components_[0, :]
plt.plot( (1+(Xmean)).cumprod() )
plt.show()

# compare to actual market
spy = get_symbol("SPY", data_loc, train_start_date, train_end_date)

plt.plot(spy['Close'].values)
plt.show()
# Out:
# Reading SPY from pickle

# %%
import gc
gc.collect()
# Out:
# 277
